# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscobarber/notebooks/blob/new/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import tensorflow_io as tfio
import torch
import librosa
def pad_to_multiple_of_1024(tensor):
    pad_size = 1024 - (tf.shape(tensor)[0] % 1024)
    return tf.cast(tf.pad(tensor, [[0, pad_size]]), tf.float32)

def apply_spectrogram(tensor):
    spectrogram = tfio.audio.spectrogram(tensor, 256, 256, 64, name=None)
    #log_spectrogram = tf.math.log(spectrogram + 1e-6)
    # Clip values to a specific range (e.g., -10 to 10)
    # Equivalent of librosa.power_to_db
    log_ref = 5e-0
    power_to_db = 10.0 * tf.math.log(spectrogram + 1e-6) / tf.math.log(10.0)
    power_to_db = power_to_db - 10.0 * tf.math.log(log_ref) / tf.math.log(10.0)
    #power_to_db = librosa.power_to_db(spectrogram,ref=log_ref)
    #clipped_spectrogram = tf.clip_by_value(power_to_db, 0.0, 1.0)
    #return clipped_spectrogram
    return power_to_db
def calculate_spectrogram_with_librosa(audio):
    """Calculates spectrogram using Torch and converts to power-to-dB using librosa."""

    # Use tf.py_function to execute NumPy/Torch code within TensorFlow graph
    spectrogram_tf = tf.py_function(
        _calculate_spectrogram_with_librosa_numpy,
        [audio],  # Input tensor to tf.py_function
        tf.float32  # Output data type
    )

    return spectrogram_tf

def _calculate_spectrogram_with_librosa_numpy(audio):
    """Helper function to perform NumPy/Torch operations."""

    # Convert TensorFlow tensor to NumPy array
    audio_np = audio.numpy()

    # Calculate spectrogram using Torch
    y = torch.from_numpy(audio_np).float()
    windowsize = 256
    window = torch.hann_window(windowsize)
    S = torch.stft(y, windowsize, window=window, return_complex=False)

    # Discard phase information
    mag = S.pow(2).sum(2).sqrt()
    ms = mag.numpy()

    # Define log_ref for librosa.power_to_db
    log_ref = np.max(ms)
    spectrogram_db = librosa.power_to_db(ms, ref=log_ref)
    spectrogram_db = spectrogram_db.T

    return tf.convert_to_tensor(spectrogram_db, dtype=tf.float32)
def apply_gl(tensor):
    log_ref = 5e-0
    tensor = tf.pow(10.0, (tensor / 10.0)) * log_ref
    return tfio.audio.inverse_spectrogram(tensor, 256, 256, 64, iterations=30)
def split_sizes_calc(num_blocks):
    split_sizes = [16] * num_blocks
    return split_sizes
def split_into_blocks(tensor, block_size=1024):
    tensor_length = tf.shape(tensor)[0]
    num_blocks = tensor_length // (block_size // 64)
    #split_sizes = [16] * num_blocks
    #split_sizes = tf.numpy_function(split_sizes_calc, [num_blocks], [tf.float32])
    #split_sizes = tf.cast(tf.repeat(16, num_blocks), dtype=tf.int32)
    #split_sizes = tf.reshape(split_sizes, [-1])
    #print(split_sizes)
    #tf.print("num_blocks:", num_blocks)
    #tf.print("num_blocks:", split_sizes)
    #split_sizes = [16] * num_blocks
    #splits = tf.split(tensor, num_or_size_splits=split_sizes, axis=0)#tf.stack()
    #flatten = [tf.reshape(block, [-1]) for block in splits]
    #return tf.stack(splits)
    # Use tf.while_loop to iterate and split dynamically
    splits = tf.TensorArray(dtype=tensor.dtype, size=0, dynamic_size=True)
    i = tf.constant(0)

    def condition(i, splits):
        return i < num_blocks

    def body(i, splits):
        block = tensor[i * (block_size // 64):(i + 1) * (block_size // 64)]
        splits = splits.write(i, block)
        return i + 1, splits

    _, splits = tf.while_loop(condition, body, [i, splits])

    return splits.stack()

def flatten(tensor):
    """Flattens a tensor into a 1-D tensor."""
    return tf.reshape(tensor, [-1])

#def split_into_blocks_np(tensor, block_size=1024):
#    tensor_length = tensor.shape[0]
#    num_blocks = tensor_length // (block_size // 64)
#    split_size = block_size // 64
#    splits = np.array_split(tensor, num_blocks)
#    return splits
#def split_into_blocks(tensor, block_size=1024):
#    splits = tf.numpy_function(split_into_blocks_np, [tensor, block_size], [tf.float32])
#    return tf.data.Dataset.from_tensor_slices(splits)
def group_back(tensor):
    original_shape = tf.shape(tensor)
    return tf.reshape(tensor, [-1, original_shape[2]])

def process_dataset(dataset):
    dataset = dataset.map(lambda x: x['audio'])
    dataset = dataset.map(lambda x: pad_to_multiple_of_1024(x))
    #dataset = dataset.map(lambda x: apply_spectrogram(x))
    dataset = dataset.map(lambda x: calculate_spectrogram_with_librosa(x))

    # Calculate the minimum and maximum values across the entire dataset
    min_value = dataset.reduce(
        tf.constant(np.inf, dtype=tf.float32),  # Initial value
        lambda min_so_far, spectrogram: tf.math.minimum(min_so_far, tf.math.reduce_min(spectrogram))
    )
    max_value = dataset.reduce(
        tf.constant(-np.inf, dtype=tf.float32),  # Initial value
        lambda max_so_far, spectrogram: tf.math.maximum(max_so_far, tf.math.reduce_max(spectrogram))
    )

    # Clip and scale spectrograms to the range [0, 1] while preventing 0 minimum
    epsilon = 1e-6  # Small value to prevent 0 minimum
    dataset = dataset.map(lambda x: (x - min_value + epsilon) / (max_value - min_value + 2 * epsilon))




    #dataset = dataset.map(lambda x: split_into_blocks(x))
    dataset = dataset.flat_map(lambda x: tf.data.Dataset.from_tensor_slices(split_into_blocks(x)))
    dataset = dataset.map(lambda x: flatten(x))
    dataset = dataset.map(lambda x: (x, x))
    #dataset = dataset.map(lambda x: group_back(x))
    #dataset = dataset.map(lambda x: apply_gl(x))
    return dataset, max_value

train_dataset = tfds.load('spoken_digit', split='train', as_supervised=False)
processed_dataset, max_value = process_dataset(train_dataset)
tf.print(processed_dataset)
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None,), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %%
import requests
import zipfile
import os

url = "https://zenodo.org/record/10810044/files/SpokeN-100.zip"
local_filename = "SpokeN-100.zip"

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-8f9dd52e8000> in <cell line: 0>()
#       9     r.raise_for_status()
#      10     with open(local_filename, 'wb') as f:
# ---> 11         for chunk in r.iter_content(chunk_size=8192):
#      12             f.write(chunk)
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1066                 data = self.read(amt=amt, decode_content=decode_content)
#    1067
#    1068                 if data:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     953                 return self._decoded_buffer.get(amt)
#     954
# --> 955         data = self._raw_read(amt)
#     956
#     957         flush_decoder = amt is None or (amt != 0 and not data)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _raw_read(self, amt, read1)
#     877
#     878         with self._error_catcher():
# --> 879             data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     880             if amt is not None and amt != 0 and not data:
#     881                 # Platform-specific: Buggy versions of Python.
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _fp_read(self, amt, read1)
#     860         else:
#     861             # StringIO doesn't like amt=None
# --> 862             return self._fp.read(amt) if amt is not None else self._fp.read()
#     863
#     864     def _raw_read(
#
# /usr/lib/python3.11/http/client.py in read(self, amt)
#     471                 # clip the read to the "end of response"
#     472                 amt = self.length
# --> 473             s = self.fp.read(amt)
#     474             if not s and amt:
#     475                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with zipfile.ZipFile(local_filename, 'r') as zip_ref:
    zip_ref.extractall("SpokeN-100")

# %%
import os
import librosa
import numpy as np

german_data_path = os.path.join("SpokeN-100", "SpokeN-100", "english_numbers")

# List to store the audio data
audio_data = []

# Recursively iterate through all subfolders
for root, dirs, files in os.walk(german_data_path):
    for filename in files:
        if filename.endswith(".wav"):
            file_path = os.path.join(root, filename)
            # Load the audio file
            audio, sr = librosa.load(file_path, sr=16000)
            # Append the audio data to the list
            audio_data.append(audio)

print(len(audio_data))
# Out:
# 3200

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten,Reshape, BatchNormalization

#processed_dataset = processed_dataset.map(lambda x: (x, x))
FRAME_LENGTH=2064
batched_dataset = processed_dataset.batch(64)
# Define the autoencoder model

# Define the autoencoder model
input_img = Input(shape=(129*16,))
encoded = Dense(256, activation='relu')(input_img)
x = Dense(500, activation="sigmoid")(encoded)
x = BatchNormalization()(x)
x = Dense(500, activation="sigmoid")(x)
x = BatchNormalization()(x)
decoded = Dense(FRAME_LENGTH, activation='sigmoid')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss="mse")

# Train the autoencoder
with tf.device('/GPU:0'):
  autoencoder.fit(batched_dataset,  #batched_dataset, #X_train,X_train,
                  epochs=20,
                  batch_size=64,
                  shuffle=True,
                  validation_data=(X_test,X_test)
                  )
# Out:
# Epoch 1/20
#     144/Unknown 14s 78ms/step - loss: 0.0246
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 0.0244 - val_loss: 0.0440
# Epoch 2/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 14s 99ms/step - loss: 0.0047 - val_loss: 0.0281
# Epoch 3/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 18s 80ms/step - loss: 0.0036 - val_loss: 0.0155
# Epoch 4/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - loss: 0.0031 - val_loss: 0.0135
# Epoch 5/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 0.0029 - val_loss: 0.0188
# Epoch 6/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0028 - val_loss: 0.0184
# Epoch 7/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0027 - val_loss: 0.0170
# Epoch 8/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 20s 75ms/step - loss: 0.0026 - val_loss: 0.0152
# Epoch 9/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - loss: 0.0025 - val_loss: 0.0153
# Epoch 10/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - loss: 0.0024 - val_loss: 0.0167
# Epoch 11/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 19s 71ms/step - loss: 0.0024 - val_loss: 0.0173
# Epoch 12/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.0023 - val_loss: 0.0162
# Epoch 13/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0023 - val_loss: 0.0153
# Epoch 14/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - loss: 0.0023 - val_loss: 0.0147
# Epoch 15/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 21s 78ms/step - loss: 0.0022 - val_loss: 0.0143
# Epoch 16/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 0.0022 - val_loss: 0.0137
# Epoch 17/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - loss: 0.0022 - val_loss: 0.0130
# Epoch 18/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.0022 - val_loss: 0.0126
# Epoch 19/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 12s 79ms/step - loss: 0.0022 - val_loss: 0.0125
# Epoch 20/20
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 0.0021 - val_loss: 0.0128

# %%
for audio in processed_dataset.take(3):
    print(audio)
# Out:
# (<tf.Tensor: shape=(2064,), dtype=float32, numpy=
# array([-1925187. , -2978396. , -3701891. , ..., -5333008.5, -6580861.5,
#        -5806366.5], dtype=float32)>, <tf.Tensor: shape=(2064,), dtype=float32, numpy=
# array([-1925187. , -2978396. , -3701891. , ..., -5333008.5, -6580861.5,
#        -5806366.5], dtype=float32)>)
# (<tf.Tensor: shape=(2064,), dtype=float32, numpy=
# array([ -1746327.,  -2589284.,  -5087391., ..., -20971520., -20971520.,
#        -20971520.], dtype=float32)>, <tf.Tensor: shape=(2064,), dtype=float32, numpy=
# array([ -1746327.,  -2589284.,  -5087391., ..., -20971520., -20971520.,
#        -20971520.], dtype=float32)>)
# (<tf.Tensor: shape=(2064,), dtype=float32, numpy=
# array([-2071813., -2869303., -5522310., ..., -4776242., -4733111.,
#        -4740799.], dtype=float32)>, <tf.Tensor: shape=(2064,), dtype=float32, numpy=
# array([-2071813., -2869303., -5522310., ..., -4776242., -4733111.,
#        -4740799.], dtype=float32)>)

# %%
# @title Hearing old
from torch_specinv import griffin_lim
import time
def audio_hearing( audio, gl="default"):
    sp_sz = int(time_long)
    samples = np.append(audio, np.random.randn(sp_sz-audio.shape[0]%sp_sz)*10, axis=0)
    y = torch.from_numpy(samples.astype("float32"))
    windowsize = 256
    window = torch.hann_window(windowsize)
    S = torch.stft(y, windowsize, window=window, return_complex=False)
    mag = S.pow(2).sum(2).sqrt()
    num = mag.numpy()

    ms=librosa.power_to_db(num, ref=log_ref)
    n_ms = samples.shape[0]//sp_sz
    ms = ms[:,:(n_ms*16)]
    ms2 = np.expand_dims(ms, axis=0)
    lms = np.split(ms2, n_ms, axis=2)
    ms2 = np.concatenate(lms)
    msrs = np.reshape(ms2/clip, [-1, 2064])


    #decrypt
    t0 = time.time()
    x_decoded = autoencoder.predict(msrs)
    tml=time.time()
    print( 'tiempo de ml: {}s'.  format(tml-t0))
    x_decoded = np.reshape(x_decoded, [-1, ms2.shape[1], ms2.shape[2]])
    lms = np.split(x_decoded, x_decoded.shape[0], axis=0)
    x_decoded2 = np.concatenate(lms,axis=2)
    x_decoded3 = np.reshape(x_decoded2, [ x_decoded2.shape[1], x_decoded2.shape[2]])
    x_decoded3 = x_decoded3 * (X_max - X_min) + X_min  # Reverse scaling
    comp3 = librosa.core.db_to_power(x_decoded3, ref=log_ref)
    #print('shape', num.shape)
    telse=time.time()
    print( 'tiempo de else: {}s'.  format(telse-tml))

    try:
      if gl=="default":
        yhat = griffin_lim(torch.from_numpy(comp3), maxiter=100, alpha=0.3, window=window)
      tgl=time.time()
      print( 'tiempo de gl: {}s'.  format(tgl-telse))
      #mag = trsfn(y)
    #yhat = RTISI_LA(mag, look_ahead=-1, asymmetric_window=False, max_iter=25,
    #alpha=0.99, verbose=1)

      return yhat.numpy()

    except:
      pass

# %%
# @title Hearing new
def audio_hearing_new(audio):
    """Processes the input audio, feeds to the autoencoder, and recovers the audio.

    Args:
        audio: The input audio tensor.

    Returns:
        The recovered audio tensor.
    """

    # 1. Process the input audio to get dataset elements
    audio = tf.expand_dims(audio, axis=0) # Add batch dimension
    audio = tf.cast(audio, tf.float32)
    audio = tf.reshape(audio, [-1])
    padded_audio = pad_to_multiple_of_1024(audio)
    spectrogram = apply_spectrogram(padded_audio)
    blocks = split_into_blocks(spectrogram)
    dataset = flatten(blocks)
    block_shape = [-1,16, 129]  # Assuming your blocks have this shape
    reshaped_blocks = tf.reshape(dataset, block_shape)
    blocks_list = tf.unstack(
        blocks, num=None, axis=0, name='unstack'
    )
    # Concatenate the reshaped blocks along the first axis (axis=0)
    merged_spectrogram = tf.concat(blocks_list, axis=0)
    print(merged_spectrogram.shape)
    print(merged_spectrogram.shape)
    audio = apply_gl(merged_spectrogram)

    return audio
    #blocks = split_into_blocks(spectrogram)
    #print(blocks.shape)

# %%
fft = 256
time_long = 1024
step_size = 64
fft_step_size_ratio = int(fft/step_size)
log_ref = 5e-0

for i, element in enumerate(train_dataset.take(3)):
    if i == 2:  # Check if it's the third element (index 2)
        break
audio = audio_hearing(audio_data[1])#element["audio"])
print(audio.shape)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f4a7aaa6f20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# tiempo de ml: 1.2471814155578613s
# tiempo de else: 0.0030171871185302734s
# 100%|██████████| 200/200 [00:00<00:00, 238.90it/s, SC=-12.3, loss=1.97e+3]
# tiempo de gl: 0.8598790168762207s
# (16320,)

# %%
from IPython.display import Audio
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# prompt: giveme onw element from train_dataset

import tensorflow as tf
import tensorflow_datasets as tfds

train_dataset = tfds.load('spoken_digit', split='train', as_supervised=False)

# Get one element from the dataset
for element in train_dataset.take(3):
element

# %%
# !pip install git+https://github.com/yoyololicon/spectrogram-inversion
# Out:
# Collecting git+https://github.com/yoyololicon/spectrogram-inversion
#   Cloning https://github.com/yoyololicon/spectrogram-inversion to /tmp/pip-req-build-96d404jw
#   Running command git clone --filter=blob:none --quiet https://github.com/yoyololicon/spectrogram-inversion /tmp/pip-req-build-96d404jw
#   Resolved https://github.com/yoyololicon/spectrogram-inversion to commit 82fa16b65928c33c94ef13f34bf42f6d57960be4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from torch_specinv==0.2.1) (2.5.1+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_specinv==0.2.1) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.6.0->torch_specinv==0.2.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->torch_specinv==0.2.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6.0->torch_specinv==0.2.1) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 774.2 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.7 MB/s eta 0:00:00
# Building wheels for collected packages: torch_specinv
#   Building wheel for torch_specinv (setup.py) ... done
#   Created wheel for torch_specinv: filename=torch_specinv-0.2.1-py3-none-any.whl size=8881 sha256=7130a791909d722f828ca0f1e626ecfeedca1b30a883617fd1e202941e2b81fd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dqd47bye/wheels/9e/c7/27/9535595febbb3942e358dd5f527cbed7c4e5791e0f98739276
# Successfully built torch_specinv
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch_specinv
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torch_specinv-0.2.1

# %%
from IPython.display import Audio
Audio(audio, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install pydub tensorflow-io
# !pip install pesq
# !pip install "torchmetrics>=1.0,<2.0" #1.0.2
#!pip install "keras>=2.0<3.0" #2.12.0
#!pip install "tensorflow>=2.0<3.0" #2.12.0
# !pip install git+https://github.com/yoyololicon/spectrogram-inversion
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: tensorflow-io in /usr/local/lib/python3.11/dist-packages (0.37.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.37.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow-io) (0.37.1)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp311-cp311-linux_x86_64.whl size=275937 sha256=abbf6830b6322109811ee4d9a6233256972c3895250ff977c72792738938869d
#   Stored in directory: /root/.cache/pip/wheels/ae/f1/23/2698d0bf31eec2b2aa50623b5d93b6206c49c7155d0e31345d
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.4
# Collecting torchmetrics<2.0,>=1.0
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<2.0,>=1.0) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<2.0,>=1.0) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<2.0,>=1.0) (2.5.1+cu124)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics<2.0,>=1.0)
#   Downloading lightning_utilities-0.12.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics<2.0,>=1.0) (75.1.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.8.0->torchmetrics<2.0,>=1.0) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->torchmetrics<2.0,>=1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->torchmetrics<2.0,>=1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics<2.0,>=1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->torchmetrics<2.0,>=1.0) (3.0.2)
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 14.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.12.0-py3-none-any.whl (28 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 14.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 26.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lightning-utilities-0.12.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchmetrics-1.6.1
# Collecting git+https://github.com/yoyololicon/spectrogram-inversion
#   Cloning https://github.com/yoyololicon/spectrogram-inversion to /tmp/pip-req-build-sgh6lxvc
#   Running command git clone --filter=blob:none --quiet https://github.com/yoyololicon/spectrogram-inversion /tmp/pip-req-build-sgh6lxvc
#   Resolved https://github.com/yoyololicon/spectrogram-inversion to commit 82fa16b65928c33c94ef13f34bf42f6d57960be4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from torch_specinv==0.2.1) (2.5.1+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_specinv==0.2.1) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->torch_specinv==0.2.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->torch_specinv==0.2.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.6.0->torch_specinv==0.2.1) (3.0.2)
# Building wheels for collected packages: torch_specinv
#   Building wheel for torch_specinv (setup.py) ... done
#   Created wheel for torch_specinv: filename=torch_specinv-0.2.1-py3-none-any.whl size=8881 sha256=135886f7776398f1a3ceebdfe8446f2e32855e25db910cc311e3314918d0be50
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mxz6refa/wheels/9e/c7/27/9535595febbb3942e358dd5f527cbed7c4e5791e0f98739276
# Successfully built torch_specinv
# Installing collected packages: torch_specinv
# Successfully installed torch_specinv-0.2.1

# %%
from os import listdir
import scipy.io.wavfile as wav
from os.path import isfile, join
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import torch
from sklearn.model_selection import train_test_split
def create_specs(fft, time_long, step_size, log_ref):
  ms_list = np.zeros([0,int(fft/2)+1,int(time_long/step_size)])

  #sp_sz=2046
  sp_sz = int(time_long)
  i = 0
  for samples in audio_data:#train_dataset.map(lambda x: x['audio']):
    samples = np.append(samples, np.random.randn(sp_sz-samples.shape[0]%sp_sz)*10, axis=0)    #ms = np.transpose(pretty_spectrogram(samples.astype("float32"),fft_size=fft,step_size=step_size,log=False))

    #ms = np.transpose(pretty_spectrogram(samples.astype("float32"),fft_size=fft,step_size=step_size,log=False))
    #n_ms = samples.shape[0]//sp_sz
    #ms = np.expand_dims(librosa.power_to_db(ms,
    #                                        ref=log_ref), axis=0)
    y = torch.from_numpy(samples.astype("float32"))
    windowsize = 256
    window = torch.hann_window(windowsize)
    S = torch.stft(y, windowsize, window=window, return_complex=False)


    # discard phase information
    mag = S.pow(2).sum(2).sqrt()
    ms = mag.numpy()
    n_ms = samples.shape[0]//sp_sz
    ms = ms[:,:(n_ms*16)]
    ms = np.expand_dims(librosa.power_to_db(ms,
                                            ref=log_ref), axis=0)
    lms = np.split(ms, n_ms, axis=2)
    ms2 = np.concatenate(lms)
    ms_list = np.append(ms_list,ms2,axis=0)
  print(np.amin(ms_list))
  print(np.amax(ms_list))
  return  train_test_split(
    ms_list, test_size=0.20, random_state=42)

# %%
fft = 256
time_long = 1024
step_size = 64
fft_step_size_ratio = int(fft/step_size)
log_ref = 5e-0

# %%
X_train, X_test = create_specs(fft=fft, time_long=time_long, step_size= step_size, log_ref= log_ref)
# Out:
# -68.53067016601562
# 19.298397064208984

# %%
min=X_train.min()
max=X_train.max()


X_train = (X_train - min) / (max - min)
X_test = (X_test - min) / (max - min)

# %%
# prompt: flatten X_train and X_test

import numpy as np

def flatten_data(data):
  """Flattens the input data to a 2D array.

  Args:
    data: A 4D NumPy array with shape (num_samples, num_frequencies, num_time_frames, 1).

  Returns:
     A 2D NumPy array.
  """

  num_samples = data.shape[0]
  flattened_data = data.reshape(num_samples, -1)
  return flattened_data

X_train = flatten_data(X_train)
X_test = flatten_data(X_test)

# %%
X_min=min
X_max=max
