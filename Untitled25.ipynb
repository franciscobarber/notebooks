# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscobarber/notebooks/blob/DCT/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: create a ML flow were audios are loaded from ljspeech dataset using tensorflo tfds, this are divided into audios of arrays of 1024 samples (padded if needed) and then given to an autoencoder with a one layer encoder and 2 decoder layers and a latent space of 256. Train it with the L2 of the DCTs but aldo add a test function to see the PESQ from an audio that goes through the entire process. The input and output from the autoencoder is the DCT, and the DCT should be preformed after the padding but before the chunking

# !pip install tensorflow tensorflow-datasets librosa pystoi

import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import librosa
from pystoi import stoi
import matplotlib.pyplot as plt
import gc
# Define hyperparameters
BUFFER_SIZE = 10000
BATCH_SIZE = 64
SAMPLE_RATE = 22050
FRAME_LENGTH = 1024
LATENT_DIM = 256
EPOCHS = 10


def preprocess_audio(example):
    audio = tf.audio.decode_wav(example["audio"], desired_channels=1)
    audio = tf.squeeze(audio.audio, axis=-1)
    audio = tf.cast(audio, tf.float32)

    # Padding
    padding_length = FRAME_LENGTH - tf.shape(audio)[0] % FRAME_LENGTH
    audio = tf.pad(audio, [[0, padding_length]])

    # DCT
    dct_audio = tf.signal.dct(audio)

    #Chunking
    num_frames = tf.shape(dct_audio)[0] // FRAME_LENGTH
    dct_audio = tf.reshape(dct_audio[:num_frames * FRAME_LENGTH], (num_frames, FRAME_LENGTH))

    return dct_audio


# Load LJ Speech dataset
def load():
  #train_dataset = tfds.load('ljspeech')
  #ds = train_dataset['train']

  train_dataset = tfds.load('ljspeech', split=['train[2%:]'])
  ds = train_dataset[0]
  print(len(train_dataset))
  temp = list(map(lambda x: x['speech'], ds))

  dataset =list( map(lambda x: x.numpy(), temp))
  del temp
  del ds
  return dataset
dataset = load()
dataset=dataset[:1000]

gc.collect()
# Preprocess the dataset
dataset = dataset.map(preprocess_audio, num_parallel_calls=tf.data.AUTOTUNE)
dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.AUTOTUNE)


# Define the autoencoder model
encoder = tf.keras.layers.Dense(LATENT_DIM, activation='relu')
decoder_layer1 = tf.keras.layers.Dense(512, activation='relu')
decoder_layer2 = tf.keras.layers.Dense(FRAME_LENGTH, activation='linear')  # Linear activation for reconstruction

def autoencoder(x):
    encoded = encoder(x)
    decoded = decoder_layer1(encoded)
    decoded = decoder_layer2(decoded)
    return decoded


# Create the model
input_tensor = tf.keras.layers.Input(shape=(FRAME_LENGTH,))
output_tensor = autoencoder(input_tensor)
model = tf.keras.Model(inputs=input_tensor, outputs=output_tensor)

# Compile the model with custom loss (L2 on DCT)
model.compile(optimizer='adam', loss='mse')


# Training loop
model.fit(dataset, epochs=EPOCHS)


def test_pesq(audio_example):
    # Preprocessing for a single audio example
    dct_audio = preprocess_audio(audio_example)

    # Inference through the autoencoder
    reconstructed_dct = model.predict(dct_audio)


    # Inverse DCT
    reconstructed_audio = tf.signal.idct(tf.reshape(reconstructed_dct, [-1]))

    # Clip to valid range
    reconstructed_audio = tf.clip_by_value(reconstructed_audio, -1.0, 1.0)

    #Remove padding
    original_audio = tf.audio.decode_wav(audio_example["audio"], desired_channels=1)
    original_audio = tf.squeeze(original_audio.audio, axis=-1)

    # Calculate PESQ
    pesq_score = stoi(original_audio.numpy(), reconstructed_audio.numpy(), SAMPLE_RATE)
    print(f"PESQ score: {pesq_score}")


# Example usage of the test function (requires a single audio example from the dataset)
for example in dataset.take(1): # Takes a batch of size 64
  for single_example in example:
    test_pesq(single_example)
    break #process only one example for now
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1605c8557e8c> in <cell line: 0>()
#      52   del ds
#      53   return dataset
# ---> 54 dataset = load()
#      55 dataset=dataset[:1000]
#      56
#
# <ipython-input-1-1605c8557e8c> in load()
#      43   #ds = train_dataset['train']
#      44
# ---> 45   train_dataset = tfds.load('ljspeech', split=['train[2%:]'])
#      46   ds = train_dataset[0]
#      47   print(len(train_dataset))
#
# /usr/local/lib/python3.11/dist-packages/tensorflow_datasets/core/logging/__init__.py in __call__(self, function, instance, args, kwargs)
#     174     metadata = self._start_call()
#     175     try:
# --> 176       return function(*args, **kwargs)
#     177     except Exception:
# ...
